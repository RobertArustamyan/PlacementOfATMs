# %%
import folium
from utils.generate_user_coordinates import generate_users_in_quadrilateral
from utils.users_living_quadrilateral_reading import get_living_quadrilateral_data
from utils.ordering import order_point_in_dictionary
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Define the map centered around Leoben
leoben_coordinates = (47.38, 15.095)
# Creating map starting in leoben
user_map = folium.Map(location=leoben_coordinates, zoom_start=15)

# %%
# Loading dataset of bounds
test_data_name = 'LeobenUserLivingSquares2Test.csv'
data = get_living_quadrilateral_data(fr"{os.getenv('USERS_DATA_PATH')}\{test_data_name}")

data = order_point_in_dictionary(data)

# %%
for bounds in data.values():
    # Comment the line below to not generate users and see only bounds!
    generated_users = generate_users_in_quadrilateral(bounds, 50)
    for bound in bounds:
        folium.Marker(location=bound, icon=folium.Icon(color="red")).add_to(user_map)

    # Generated user adding on map. Comment following 2 lines to not see on the map
    for user in generated_users:
        folium.Marker(location=(user.latitude,user.longitude)).add_to(user_map)

    folium.PolyLine(locations=bounds + [bounds[0]], color="blue", weight=2.5, opacity=1).add_to(user_map)

# %%
user_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdcada9e60fce18f29d30a39c50ce862 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdcada9e60fce18f29d30a39c50ce862&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdcada9e60fce18f29d30a39c50ce862 = L.map(
#                 &quot;map_bdcada9e60fce18f29d30a39c50ce862&quot;,
#                 {
#                     center: [47.38, 15.095],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e5e5444280a995e63fcedcd1b1c4769 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e5e5444280a995e63fcedcd1b1c4769.addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var marker_282cf0b0ece1eae3d7a77b8b2e5160cd = L.marker(
#                 [47.3865366, 15.0925787],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var icon_1e729bf213f368929e32d4f92083cd61 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_282cf0b0ece1eae3d7a77b8b2e5160cd.setIcon(icon_1e729bf213f368929e32d4f92083cd61);
#
#
#             var marker_0958f988df154d85adad975de09cbcfa = L.marker(
#                 [47.3874171, 15.0931351],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var icon_8f1aca477ee16028950526b69c12be5c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_0958f988df154d85adad975de09cbcfa.setIcon(icon_8f1aca477ee16028950526b69c12be5c);
#
#
#             var marker_0a498572f649ce7ae295d0bb4e4d2356 = L.marker(
#                 [47.3878482, 15.0950483],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var icon_5b17b398386bb82d1cf66c7f4cfa7604 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_0a498572f649ce7ae295d0bb4e4d2356.setIcon(icon_5b17b398386bb82d1cf66c7f4cfa7604);
#
#
#             var marker_c56c6ab189450095d363c0a10472f544 = L.marker(
#                 [47.3869547, 15.0950698],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var icon_1af2793aa0d8458e9393f7e4823be672 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_c56c6ab189450095d363c0a10472f544.setIcon(icon_1af2793aa0d8458e9393f7e4823be672);
#
#
#             var marker_034530cbf934f3607eeb9f5c41715040 = L.marker(
#                 [47.3874006, 15.0933629],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var marker_add3773014a0c74417a094c007fc7bb3 = L.marker(
#                 [47.3868257, 15.0942203],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var marker_10a826268160b71a1eac1f2a3afdd57c = L.marker(
#                 [47.387456, 15.093646],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var marker_57c71c6dd76328d3c87ff046fee608ea = L.marker(
#                 [47.3871323, 15.0938351],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var marker_71d5166e48cb146e8d486b93b5aaf57d = L.marker(
#                 [47.3875484, 15.0941186],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var marker_4d7b8cbac27a2453def463bb0df95304 = L.marker(
#                 [47.3868076, 15.0932446],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a39c50ce862);
#
#
#             var marker_9bd52738d1dac3aace063333eaa23edc = L.marker(
#                 [47.3870681, 15.0931253],
#                 {
# }
#             ).addTo(map_bdcada9e60fce18f29d30a
