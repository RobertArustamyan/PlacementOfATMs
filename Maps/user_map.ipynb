# %%
import folium
from utils.generate_user_coordinates import generate_users_in_quadrilateral
from utils.users_living_quadrilateral_reading import get_living_quadrilateral_data
from utils.ordering import order_point_in_dictionary
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Define the map centered around Leoben
leoben_coordinates = (47.38, 15.095)
# Creating map starting in leoben
user_map = folium.Map(location=leoben_coordinates, zoom_start=15)

# %%
# Loading dataset of bounds
test_data_name = 'LeobenUserLivingSquares2Test.csv'
data = get_living_quadrilateral_data(fr"{os.getenv('USERS_DATA_PATH')}\{test_data_name}")

data = order_point_in_dictionary(data)

# %%
for bounds in data.values():
    # Comment the line below to not generate users and see only bounds!
    generated_users = generate_users_in_quadrilateral(bounds, 50)
    for bound in bounds:
        folium.Marker(location=bound, icon=folium.Icon(color="red")).add_to(user_map)

    # Generated user adding on map. Comment following 2 lines to not see on the map
    for user in generated_users:
        folium.Marker(location=(user.latitude,user.longitude)).add_to(user_map)

    folium.PolyLine(locations=bounds + [bounds[0]], color="blue", weight=2.5, opacity=1).add_to(user_map)

# %%
user_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d89fea8e549e208a160d9c06d9e9d45c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d89fea8e549e208a160d9c06d9e9d45c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d89fea8e549e208a160d9c06d9e9d45c = L.map(
#                 &quot;map_d89fea8e549e208a160d9c06d9e9d45c&quot;,
#                 {
#                     center: [47.38, 15.095],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b19704679b3616be7214117d619060a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b19704679b3616be7214117d619060a2.addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var marker_98ad89a813d71f97658a610bca7d1352 = L.marker(
#                 [47.3865366, 15.0925787],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var icon_1c3e1f79f794cf433ad2457e2bdd2a7f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_98ad89a813d71f97658a610bca7d1352.setIcon(icon_1c3e1f79f794cf433ad2457e2bdd2a7f);
#
#
#             var marker_893ec1bd8303cc5b98da60d1bc54a4f4 = L.marker(
#                 [47.3874171, 15.0931351],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var icon_331807bb100426e12abe698eb8a5fe11 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_893ec1bd8303cc5b98da60d1bc54a4f4.setIcon(icon_331807bb100426e12abe698eb8a5fe11);
#
#
#             var marker_17d9c30a4697747253966dd5f7d600cf = L.marker(
#                 [47.3878482, 15.0950483],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var icon_e79ca40e0a86b26664d98e4d1f3f4104 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_17d9c30a4697747253966dd5f7d600cf.setIcon(icon_e79ca40e0a86b26664d98e4d1f3f4104);
#
#
#             var marker_7c144e1deea75c3d09878edebcf88160 = L.marker(
#                 [47.3869547, 15.0950698],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var icon_041791530df361afec4cab18a642fe87 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_7c144e1deea75c3d09878edebcf88160.setIcon(icon_041791530df361afec4cab18a642fe87);
#
#
#             var marker_4cb9c0a63a83e2003731ce85070d1df3 = L.marker(
#                 [47.3869929, 15.0929537],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var marker_29e6956503ad5215e2c3d0988686506f = L.marker(
#                 [47.3866249, 15.0929194],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var marker_525b2bda09072f2655d8050ab342d974 = L.marker(
#                 [47.3875861, 15.0945393],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var marker_95682004188c4d94985397dd74ee7482 = L.marker(
#                 [47.3874183, 15.094239],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var marker_313efd04dd19be9c6f33173ee14d9055 = L.marker(
#                 [47.3874477, 15.0938722],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var marker_3b4a197556dc16628a525318bac7d54c = L.marker(
#                 [47.3874796, 15.0945407],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9c06d9e9d45c);
#
#
#             var marker_a588de4eb89b8e6554ea6c6edfebd8ef = L.marker(
#                 [47.3868094, 15.0928992],
#                 {
# }
#             ).addTo(map_d89fea8e549e208a160d9
