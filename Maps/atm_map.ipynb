# %%
import folium
from utils.atm_data_reading import get_atm_data

# %%
# Define the map centered around Leoben
leoben_coordinates = (47.38, 15.095)

atm_map = folium.Map(location=leoben_coordinates,zoom_start=15)

# %%
# Load ATM data from CSV
atms_data = get_atm_data(r"C:\Users\User\PycharmProjects\PlacementOfATMs\ATMsData\Leoben-73ATMsTEST.csv")

for atm in atms_data:
    folium.Marker(location=(atm.latitude,atm.longitude),popup=atm.name).add_to(atm_map)

# %%
# Display the generated map
atm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6852569f6611e330f2bb8d53c063be98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6852569f6611e330f2bb8d53c063be98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6852569f6611e330f2bb8d53c063be98 = L.map(
#                 &quot;map_6852569f6611e330f2bb8d53c063be98&quot;,
#                 {
#                     center: [47.38, 15.095],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da6fab116ceb5b35b89f4d92b8a6c690 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da6fab116ceb5b35b89f4d92b8a6c690.addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_0eb8f361fe4f89744b262ab175ed7670 = L.marker(
#                 [47.3722163, 15.0888791],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_96fb4cc06384c954a40ed9a51d901c0a = L.marker(
#                 [47.3745414, 15.0827851],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_5ca5d2e6dccf61fe65c541029613ed7a = L.marker(
#                 [47.3762851, 15.0847163],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_5078e5023c4368b9dd0558e697c89a37 = L.marker(
#                 [47.3769244, 15.0887074],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_e1f65d002af61750b46254e2723d4879 = L.marker(
#                 [47.3789877, 15.0881924],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_1b771cefc458b3b4558907a4650cd50c = L.marker(
#                 [47.3754132, 15.0845446],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_7ed68be3e1759f738d7fa4af45f7a08d = L.marker(
#                 [47.377186, 15.0781931],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_705a6030eb7477c6becd94dcbcaad735 = L.marker(
#                 [47.3764013, 15.0754895],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_0a0d4bcb8f30a426803da61de9eda246 = L.marker(
#                 [47.3760449, 15.0735672],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_3b3b0ba80cc1b773fee2dd1cb2fe6101 = L.marker(
#                 [47.3780386, 15.0668016],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_5872873b23c2e6282677f9676d1634d0 = L.marker(
#                 [47.3803925, 15.0851999],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_3c43d02e6f559ef00dcf5f7220229015 = L.marker(
#                 [47.3801114, 15.0925174],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_8525ef9ecbf5f908ec5169f0ada438f1 = L.marker(
#                 [47.3787165, 15.1032892],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_c2f39c064db8e39e89f58467bb156b5e = L.marker(
#                 [47.3822181, 15.0950494],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_2ed0c7e77df52907c34af10804ce3a35 = L.marker(
#                 [47.379674, 15.0949783],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_8a62efd55c5be6e2ae90a83c4da50e12 = L.marker(
#                 [47.3809441, 15.0962059],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_572f877fff56d95b634fa87deb13be69 = L.marker(
#                 [47.3829771, 15.09044],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_dc49220ebfca09ff48928d37d7f66317 = L.marker(
#                 [47.3856031, 15.0914725],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_f5b5a0ebc93042d7ede2a9f7a0185d5c = L.marker(
#                 [47.3847022, 15.0928351],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_41a634bad26be99047db59f3dddb1551 = L.marker(
#                 [47.3860606, 15.0958177],
#                 {
# }
#             ).addTo(map_6852569f6611e330f2bb8d53c063be98);
#
#
#             var marker_423b0803dfb164f4431f3714264e8442 = L.mark
